# %%
import numpy as np
import pandas as pd

# %%
train_path="/home/u131168/mh_one_api/data/train.csv"
test_path="/home/u131168/mh_one_api/data/test.csv"
f_traind_path="/home/u131168/mh_one_api/data/f_traind.csv"
f_traind_v1_path="/home/u131168/mh_one_api/data/f_traind_v1.csv"

f_testd_path="/home/u131168/mh_one_api/data/f_testd.csv"

train_data=pd.read_csv(train_path)
test_data=pd.read_csv(test_path)


train_data
train_data.fillna(0,inplace=True)


train_data.rename(columns = {'Story':'input','Question':'instruction','Answer':'output'}, inplace = True)
# train_data['input']=train_data.apply(lambda x: strip_input(x[0],x[4]),axis=1)
# train_data=train_data[['input','instruction','output']]
# train_data.isna().sum()
train_data=train_data[['input','instruction','output']]
train_data['input']=train_data['input'].apply(lambda x: x.replace("\n","\\"))
train_data['input']=train_data['input'].apply(lambda x: x.replace("\t","\\"))

train_data['input']=train_data['input'].apply(lambda x: f'paragraph:  '+str(x))
train_data['instruction']=train_data['instruction'].apply(lambda x: f'Answer the following question from the paragraph : Question: {x}')
train_data['output']=train_data['output'].apply(lambda x:str(x).strip())
train_data[train_data['output']=='unknown']
train_data[train_data['output']=='']
train_data=train_data[train_data['output']!='unknown']
# train_data.iloc[:100].to_csv(f_traind_path,index=False)

# train_data.isna().sum()
# train_data[:25]
# train_data.iloc[22,0]

# %%
# train_data.to_csv("/home/u131168/mh_one_api/data/train_split/full_traind1.csv",index=False)

# %%
# f_traind_v1_path="/home/u131168/mh_one_api/data/f_traind_v1.csv"
f_traind=train_data
f_traind_v1=f_traind
for i in range(2):
    f_traind_v1=pd.concat([f_traind_v1,f_traind]).reset_index(drop=True)

# f_traind_v1.to_csv(f_traind_v1_path)
f_traind_v1
# Out:
#                                                     input  \
# 0       paragraph:  CHAPTER IV. \\Notwithstanding the ...
# 1       paragraph:  (CNN) -- Polk County, Florida, det...
# 2       paragraph:  Malawi (, or ; or [maláwi]), offic...
# 3       paragraph:  CHAPTER XXXII. \\MR. GILMORE'S SUC...
# 4       paragraph:  CHAPTER XV--THE END OF THE MEETING...
# ...                                                   ...
# 197536  paragraph:  CHAPTER I--PROGRESS OF THE HOUSE \...
# 197537  paragraph:  Hong Kong (CNN) -- A car theft in ...
# 197538  paragraph:  CHAPTER III \\The morning of depar...
# 197539  paragraph:  New York (CNN) -- Two New York men...
# 197540  paragraph:  Akrotiri and Dhekelia, officially ...
#
#                                               instruction  \
# 0       Answer the following question from the paragra...
# 1       Answer the following question from the paragra...
# 2       Answer the following question from the paragra...
# 3       Answer the following question from the paragra...
# 4       Answer the following question from the paragra...
# ...                                                   ...
# 197536  Answer the following question from the paragra...
# 197537  Answer the following question from the paragra...
# 197538  Answer the following question from the paragra...
# 197539  Answer the following question from the paragra...
# 197540  Answer the following question from the paragra...
#
#                                                    output
# 0                                       mirth and sadness
# 1                                                 robbery
# 2                                                      No
# 3                                              Everything
# 4                                 with feminine intuition
# ...                                                   ...
# 197536                                               Apri
# 197537                                               grey
# 197538                                           Eleanor.
# 197539  stole Price's wallet and other personal proper...
# 197540                   strategic location of the island
#
# [197541 rows x 3 columns]

# %%
test_data
# test_data.iloc[0,0]
# Out:
#                                                    input  \
# 0      paragraph:  CHAPTER I \\ON THE HOUSEBOAT \\"Sa...
# 1      paragraph:  The Uralic languages (; sometimes ...
# 2      paragraph:  The University of Wisconsin–Madiso...
# 3      paragraph:  (CNN) -- The unexpected resignatio...
# 4      paragraph:  CHAPTER THIRTY-TWO \\TENDER TROUBL...
# ...                                                  ...
# 28543  paragraph:  CHAPTER III. \\"Nice customs curt'...
# 28544  paragraph:  CHAPTER XI. \\In the little dining...
# 28545  paragraph:  Chapter XXX. \\"I shall go on thro...
# 28546  paragraph:  Chapter XXXIV \\Violence \\\\It ha...
# 28547  paragraph:  Be home by dinnertime, Eric's moth...
#
#                                              instruction
# 0      Answer the following question from the paragra...
# 1      Answer the following question from the paragra...
# 2      Answer the following question from the paragra...
# 3      Answer the following question from the paragra...
# 4      Answer the following question from the paragra...
# ...                                                  ...
# 28543  Answer the following question from the paragra...
# 28544  Answer the following question from the paragra...
# 28545  Answer the following question from the paragra...
# 28546  Answer the following question from the paragra...
# 28547  Answer the following question from the paragra...
#
# [28548 rows x 2 columns]

# %%
test_data
test_data.fillna(0,inplace=True)


test_data.rename(columns = {'Story':'input','Question':'instruction'}, inplace = True)
# train_data['input']=train_data.apply(lambda x: strip_input(x[0],x[4]),axis=1)
# train_data=train_data[['input','instruction','output']]
# train_data.isna().sum()
# test_data=test_data[['input','instruction','output']]
test_data['input']=test_data['input'].apply(lambda x: x.replace("\n","\\"))
test_data['input']=test_data['input'].apply(lambda x: x.replace("\t","\\"))

test_data['input']=test_data['input'].apply(lambda x: f'paragraph:  '+str(x))
test_data['instruction']=test_data['instruction'].apply(lambda x: f'Answer the following question from the paragraph : Question: {x}')
# test_data['output']=test_data['output'].apply(lambda x:str(x).strip())

# test_data.to_csv(f_testd_path,index=False)

# %%
f_testd=pd.read_csv(f_testd_path)
f_testd
# Out:
#                                                    input  \
# 0      paragraph:  paragraph:  CHAPTER I \\ON THE HOU...
# 1      paragraph:  paragraph:  The Uralic languages (...
# 2      paragraph:  paragraph:  The University of Wisc...
# 3      paragraph:  paragraph:  (CNN) -- The unexpecte...
# 4      paragraph:  paragraph:  CHAPTER THIRTY-TWO \\T...
# ...                                                  ...
# 28543  paragraph:  paragraph:  CHAPTER III. \\"Nice c...
# 28544  paragraph:  paragraph:  CHAPTER XI. \\In the l...
# 28545  paragraph:  paragraph:  Chapter XXX. \\"I shal...
# 28546  paragraph:  paragraph:  Chapter XXXIV \\Violen...
# 28547  paragraph:  paragraph:  Be home by dinnertime,...
#
#                                              instruction
# 0      Answer the following question from the paragra...
# 1      Answer the following question from the paragra...
# 2      Answer the following question from the paragra...
# 3      Answer the following question from the paragra...
# 4      Answer the following question from the paragra...
# ...                                                  ...
# 28543  Answer the following question from the paragra...
# 28544  Answer the following question from the paragra...
# 28545  Answer the following question from the paragra...
# 28546  Answer the following question from the paragra...
# 28547  Answer the following question from the paragra...
#
# [28548 rows x 2 columns]

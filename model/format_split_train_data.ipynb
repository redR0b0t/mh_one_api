# %%
import numpy as np
import pandas as pd

# %%
from pprint import pprint
def strip_input(input,span_text):
    # pprint(f"got {input} and {span_text}")
    if span_text!=0:
        input=str(input)
        in_parts=input.split('\n')
        for inp in in_parts:
            if span_text in inp:
                # print(f"--------returning input={inp[:10]}")
                return inp
        # return "same as before"
        return input

    else:
        # return "same as before"
        return input

# %%
train_path="/home/u131168/mh_one_api/data/train.csv"
test_path="/home/u131168/mh_one_api/data/test.csv"
submission_path="/home/u131168/mh_one_api/data/submission.csv"

train_data=pd.read_csv(train_path)
test_data=pd.read_csv(test_path)
submission_data=pd.read_csv(submission_path)


train_data
train_data.fillna(0,inplace=True)


train_data.rename(columns = {'Story':'input','Question':'instruction','Answer':'output'}, inplace = True)
train_data['input']=train_data.apply(lambda x: strip_input(x[0],x[4]),axis=1)
# train_data=train_data[['input','instruction','output']]
# train_data.isna().sum()
train_data[:25]
# train_data.iloc[22,0]
# Out:
# /tmp/ipykernel_441240/1246545896.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   train_data['input']=train_data.apply(lambda x: strip_input(x[0],x[4]),axis=1)
#                                                 input  \
# 0   Notwithstanding the earnest injunction that Ma...
# 1   "Mr. Manieri was one of the last people ... th...
# 2   Malawi is among the smallest countries in Afri...
# 3   Harry Gilmore, the prosperous country gentlema...
# 4   Computer security, also known as cybersecurity...
# 5   'And I have no doubt that he embellished that ...
# 6   BT's origins date back to the founding of the ...
# 7   Steubenville, Ohio (CNN) -- One of the teens w...
# 8   Gymnasts sprint down a runway, which is a maxi...
# 9   But McCaw, who was left in tears as the All Bl...
# ...

# %%
# train_data.iloc[0:25000].to_csv("/home/u131168/mh_one_api/data/train_split_ss/0_25k.csv",index=False)
# train_data.iloc[25000:50000].to_csv("/home/u131168/mh_one_api/data/train_split_ss/25_50k.csv",index=False)
# train_data.iloc[50000:66611].to_csv("/home/u131168/mh_one_api/data/train_split_ss/50_66k.csv",index=False)

train_data.to_csv("/home/u131168/mh_one_api/data/train_split_ss/full_traind_ss.csv",index=False)

# %%
train1=pd.read_csv('/home/u131168/mh_one_api/data/train_split_ss/full_traind_ss.csv')
train1
# Out:
#                                                    input  \
# 0      Notwithstanding the earnest injunction that Ma...
# 1      "Mr. Manieri was one of the last people ... th...
# 2      Malawi is among the smallest countries in Afri...
# 3      Harry Gilmore, the prosperous country gentlema...
# 4      Computer security, also known as cybersecurity...
# ...                                                  ...
# 66606  The winter had been an open one. Things in the...
# 66607  Zhou had allegedly stolen the grey Toyota SUV ...
# 66608  "My Eleanor, this should not be!" said Reginal...
# 66609  Police say the two men shouted "anti-gay remar...
# 66610  The Sovereign Base Areas were created in 1960 ...
#
#                                              instruction  span_start  \
# 0                            What emotions did she show?       199.0
# 1               What do police believe the motive to be?       428.0
# 2                                 Is it a large country?       653.0
# ...

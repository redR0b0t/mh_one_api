# %%
import numpy as np
import pandas as pd

# %%
train_path="/home/u131168/mh_one_api/data/train.csv"
test_path="/home/u131168/mh_one_api/data/test.csv"
submission_path="/home/u131168/mh_one_api/data/submission.csv"

train_data=pd.read_csv(train_path)
test_data=pd.read_csv(test_path)
submission_data=pd.read_csv(submission_path)

# %%
# train_data=train_data.drop(["span_start","span_end","span_text"],axis=1)
# train_data
# test_data
# submission_data
# from intel_extension_for_transformers.neural_chat import build_chatbot
# instruction=pd.Series(train_data['Question'],index=1,name='instruction')
# input=pd.Series(train_data['Story'],index=1,name='input')
# output=pd.Series(train_data['Answer'],index=1,name='output')

# ftd=pd.DataFrame(instruction,input,output)
# ftd

# train_data.rename(columns={"Story": "input", "Question": "instruction","Answer":"output"}, inplace=True)

train_data
# Out:
#                                                    input  \
# 0      CHAPTER IV. \n\nNotwithstanding the earnest in...
# 1      (CNN) -- Polk County, Florida, detectives arre...
# 2      Malawi (, or ; or [maláwi]), officially the Re...
# 3      CHAPTER XXXII. \n\nMR. GILMORE'S SUCCESS. \n\n...
# 4      Computer security, also known as cybersecurity...
# ...                                                  ...
# 66606  CHAPTER I--PROGRESS OF THE HOUSE \n\nThe winte...
# 66607  Hong Kong (CNN) -- A car theft in China that s...
# 66608  CHAPTER III \n\nThe morning of departure arriv...
# 66609  New York (CNN) -- Two New York men accused of ...
# 66610  Akrotiri and Dhekelia, officially the Sovereig...
#
#                                              instruction  \
# 0                            What emotions did she show?
# 1               What do police believe the motive to be?
# 2                                 Is it a large country?
# ...

# %%
train_data.to_csv('./formatted_td.csv',index=False)

# %%
ftd=pd.read_csv("./formatted_td.csv")
ftd
# Out:
#                                                    input  \
# 0      CHAPTER IV. \n\nNotwithstanding the earnest in...
# 1      (CNN) -- Polk County, Florida, detectives arre...
# 2      Malawi (, or ; or [maláwi]), officially the Re...
# 3      CHAPTER XXXII. \n\nMR. GILMORE'S SUCCESS. \n\n...
# 4      Computer security, also known as cybersecurity...
# ...                                                  ...
# 66606  CHAPTER I--PROGRESS OF THE HOUSE \n\nThe winte...
# 66607  Hong Kong (CNN) -- A car theft in China that s...
# 66608  CHAPTER III \n\nThe morning of departure arriv...
# 66609  New York (CNN) -- Two New York men accused of ...
# 66610  Akrotiri and Dhekelia, officially the Sovereig...
#
#                                              instruction  \
# 0                            What emotions did she show?
# 1               What do police believe the motive to be?
# 2                                 Is it a large country?
# ...

# %%
print("hello")
# Out:
# hello
